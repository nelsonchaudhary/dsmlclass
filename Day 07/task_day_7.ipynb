# %% [markdown]
# #create a dictionary to store student name,age, and faculty.

# %%
data = dict({
    "name"   : "Nelson",
    "age"    : 23,
    "faculty": "IT"
})
data
# Out:
# {'name': 'Nelson', 'age': 23, 'faculty': 'IT'}

# %% [markdown]
# #add a new key called phone to an existing dictionary.

# %%
data.setdefault("phone",9816933954)
data
# Out:
# {'name': 'Nelson', 'age': 23, 'faculty': 'IT', 'phone': 9816933954}

# %% [markdown]
# #update the value of age.

# %%
data = dict({
    "name"   : "Nelson",
    "age"    : 23,
    "faculty": "IT",
    "age"    : 24
})
data
# Out:
# {'name': 'Nelson', 'age': 24, 'faculty': 'IT'}

# %% [markdown]
# #add a key city and delete the key city

# %%
data.setdefault("city","ktm")
data
# Out:
# {'name': 'Nelson', 'age': 24, 'faculty': 'IT', 'city': 'ktm'}

# %%
del data["city"]

# %%
data
# Out:
# {'name': 'Nelson', 'age': 24, 'faculty': 'IT'}
