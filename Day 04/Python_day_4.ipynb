# %% [markdown]
# #STRING

# %%
data = "hello"
data1 = "hello"

# %%
type(data)
# Out:
# str

# %%
type(data1)
# Out:
# str

# %%
data = "python"

# %%
data[0]
# Out:
# 'p'

# %%
data[-5]
# Out:
# 'y'

# %%
data = "hello's,i am a boy"
data
# Out:
# "hello's,i am a boy"

# %%
data1 = 'hello this is a "man"'
data
# Out:
# 'hello this is a "boy"'

# %% [markdown]
# #STRING OPERATION

# %%
data +" " +data1
# Out:
# 'hello\'s,i am a boy hello this is a "man"'

# %%
data="nelson"
data1="Chaudhary"
result=data +data1

# %%
result
# Out:
# 'nelson Chaudhary'

# %%
result=data+ " " +data1
result
# Out:
# 'nelson Chaudhary'

# %%
data1 *3
# Out:
# 'ChaudharyChaudharyChaudhary'

# %%
data1[1]
# Out:
# 'h'

# %%
data1[-2]
# Out:
# 'r'

# %% [markdown]
# #SLICING
# [start:end]

# %%
data5="hello i who are you"

# %%
data5[1:4]
# Out:
# 'ell'

# %% [markdown]
# [start:end;step]

# %%
data5[2: 20 :2]
# Out:
# 'loiwoaeyu'

# %%
data6="python"

# %%
data6[0:2]
# Out:
# 'py'

# %%
data6[:-4]
# Out:
# 'py'

# %%
data6[:3]
# Out:
# 'pyt'

# %%
data6[::]
# Out:
# 'python'

# %%
data6[::-1]
# Out:
# 'nohtyp'

# %% [markdown]
# #LENGTH

# %%
data7="hello who are you"
len(data7)
# Out:
# 17

# %% [markdown]
# #STRING OPERATION

# %% [markdown]
# #UPPER

# %%
string = "hello"
string.upper()
# Out:
# 'HELLO'

# %% [markdown]
# #LOWER

# %%
string1 = "HELLO"
string1.lower()
# Out:
# 'hello'

# %% [markdown]
# #TITLE

# %%
string3 = "hello world"
string3.title()
# Out:
# 'Hello World'

# %% [markdown]
# #STRIP
# #removes leading and trailing whitespace

# %%
string4 ="        nelson chaudhary        "
string4.strip()
# Out:
# 'nelson chaudhary'

# %%
string5 = "#####python######"
string5.strip("#")
# Out:
# 'python'

# %% [markdown]
# #REPLACE

# %%
string6="i like tea"
string6.replace("tea","coffee")
# Out:
# 'i like coffee'

# %% [markdown]
# #SPLIT

# %%
string="apple,banana,cat"
string.split()
# Out:
# ['apple,banana,cat']

# %%
string="apple,banana,cat"
string.split(",")
# Out:
# ['apple', 'banana', 'cat']

# %%
string="apple,banana,cat"
string.split("a")
# Out:
# ['', 'pple,b', 'n', 'n', ',c', 't']

# %%
string="apple,banana,cat"
string.split("b")
# Out:
# ['apple,', 'anana,cat']

# %% [markdown]
# #JOIN

# %%
letters = ["p","y","t","h","o","n"]#list
print("".join(letters))
# Out:
# python

# %%
text = "i like java"
text.endswith("java")
# Out:
# True

# %%
text = "i like java"
text.endswith("php")
# Out:
# False

# %% [markdown]
# #INTERVIEW QUESTION
# #difference between list and tuple
# #list le sabai kam garcha tara pani kina tuple chayiyeko
