# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/data file/survey_student.csv')

# %%
data.head()
# Out:
#                    Timestamp Your Sex?  \
# 0  2024/03/07 5:12:01 pm EET    Female
# 1  2024/03/07 5:12:08 pm EET      Male
# 2  2024/03/07 5:12:25 pm EET      Male
# 3  2024/03/07 5:12:28 pm EET      Male
# 4  2024/03/07 5:13:00 pm EET    Female
#
#    Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                        76.0
# 1                                        89.0
# 2                                        76.0
# 3                                        89.0
# 4                                        74.0
#
#   What year were you in last year (2023) ?  \
# 0                                 2nd Year
# 1                                 2nd Year
# 2                                 1st Year
# 3                                 2nd Year
# 4                                 2nd Year
#
#   What faculty does your degree fall under?  \
# 0                    Arts & Social Sciences
# 1            Economic & Management Sciences
# ...

# %%
data.shape
# Out:
# (406, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 17 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Timestamp                                                                                          406 non-null    object
#  1   Your Sex?                                                                                          404 non-null    object
#  2   Your Matric (grade 12) Average/ GPA (in %)                                                         399 non-null    float64
#  3   What year were you in last year (2023) ?                                                           333 non-null    object
# ...

# %%
data.describe()
# Out:
#        Your Matric (grade 12) Average/ GPA (in %)  \
# count                                  399.000000
# mean                                    77.989724
# std                                      7.048618
# min                                     34.000000
# 25%                                     74.000000
# 50%                                     78.000000
# 75%                                     83.000000
# max                                     99.000000
#
#        Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)
# count                                         320.000000
# mean                                           66.268469
# std                                             9.147906
# min                                            30.000000
# 25%                                            60.000000
# 50%                                            65.000000
# 75%                                            73.000000
# ...

# %% [markdown]
# #column names

# %%
data.columns
# Out:
# Index(['Timestamp', 'Your Sex?', 'Your Matric (grade 12) Average/ GPA (in %)',
#        'What year were you in last year (2023) ?',
#        'What faculty does your degree fall under?',
#        'Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)',
#        'Your Accommodation Status Last Year (2023)',
#        'Monthly Allowance in 2023', 'Were you on scholarship/bursary in 2023?',
#        'Additional amount of studying (in hrs) per week',
#        'How often do you go out partying/socialising during the week? ',
#        'On a night out, how many alcoholic drinks do you consume?',
#        'How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)',
#        'How many modules have you failed thus far into your studies?',
#        'Are you currently in a romantic relationship?',
#        'Do your parents approve alcohol consumption?',
#        'How strong is your relationship with your parent/s?'],
# ...

# %% [markdown]
# #creating cleaner column names

# %%
data.columns = ['Timestamp','Sex','Matric_GPA','Year_2023','Faculty','Academic_GPA_2023','Accommodation','Monthly_Allowance','Scholarship','Study_hours','Socialsing','Alcohol_Drinks','Classes_Missed','Modules_Failed','Relationship','Parent_Approval','Parent_Relationship']

# %%
data.head()
# Out:
#                    Timestamp     Sex  Matric_GPA Year_2023  \
# 0  2024/03/07 5:12:01 pm EET  Female        76.0  2nd Year
# 1  2024/03/07 5:12:08 pm EET    Male        89.0  2nd Year
# 2  2024/03/07 5:12:25 pm EET    Male        76.0  1st Year
# 3  2024/03/07 5:12:28 pm EET    Male        89.0  2nd Year
# 4  2024/03/07 5:13:00 pm EET  Female        74.0  2nd Year
#
#                           Faculty  Academic_GPA_2023  \
# 0          Arts & Social Sciences               72.0
# 1  Economic & Management Sciences               75.0
# 2                    AgriSciences               55.0
# 3                     Engineering               84.0
# 4          Arts & Social Sciences               52.0
#
#                                      Accommodation Monthly_Allowance  \
# 0  Private accommodation/ stay with family/friends    R 4001- R 5000
# 1  Private accommodation/ stay with family/friends   R 7001 - R 8000
# 2  Private accommodation/ stay with family/friends    R 4001- R 5000
# ...

# %% [markdown]
# #missing values

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     2
# Matric_GPA              7
# Year_2023              73
# Faculty                 7
# Academic_GPA_2023      86
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          3
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     3
# dtype: int64

# %% [markdown]
# #missing value in percentage

# %%
(data.isnull().sum() / len(data)) * 100
# Out:
# Timestamp               0.000000
# Sex                     0.492611
# Matric_GPA              1.724138
# Year_2023              17.980296
# Faculty                 1.724138
# Academic_GPA_2023      21.182266
# Accommodation           5.665025
# Monthly_Allowance       7.635468
# Scholarship             1.970443
# Study_hours             0.738916
# Socialsing              0.492611
# Alcohol_Drinks          0.492611
# Classes_Missed          0.738916
# Modules_Failed          0.738916
# Relationship            0.738916
# Parent_Approval         0.985222
# Parent_Relationship     0.738916
# dtype: float64

# %% [markdown]
# #Duplicate Data

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Sex, Matric_GPA, Year_2023, Faculty, Academic_GPA_2023, Accommodation, Monthly_Allowance, Scholarship, Study_hours, Socialsing, Alcohol_Drinks, Classes_Missed, Modules_Failed, Relationship, Parent_Approval, Parent_Relationship]
# Index: []

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (406, 17)

# %% [markdown]
# No duplicate data

# %% [markdown]
# #Categorical Data
#  column data classification

# %%
data["Sex"].value_counts(dropna=False)
# Out:
# Sex
# Male      216
# Female    188
# NaN         2
# Name: count, dtype: int64

# %%
data["Faculty"].value_counts(dropna=False)
# Out:
# Faculty
# Economic & Management Sciences    211
# Science                            56
# Arts & Social Sciences             47
# Engineering                        37
# AgriSciences                       22
# Medicine and Health Services       10
# Law                                10
# NaN                                 7
# Education                           6
# Name: count, dtype: int64

# %%
data["Accommodation"].value_counts(dropna=False)
# Out:
# Accommodation
# Private accommodation/ stay with family/friends    335
# Non-private accommodation ie. Res                   48
# NaN                                                 23
# Name: count, dtype: int64

# %% [markdown]
# #Numerical Data Stored as categories/Text

# %%
data["Monthly_Allowance"].value_counts(dropna=False)
# Out:
# Monthly_Allowance
# R 4001- R 5000     159
# R 5001 - R 6000    101
# R 6001 - R 7000     58
# NaN                 31
# R 7001 - R 8000     30
# R 8000+             27
# Name: count, dtype: int64

# %%
data["Study_hours"].value_counts(dropna=False)
# Out:
# Study_hours
# 8+     114
# 3-5    105
# 1-3     83
# 5-8     81
# 0       20
# NaN      3
# Name: count, dtype: int64

# %%
data["Alcohol_Drinks"].value_counts(dropna=False)
# Out:
# Alcohol_Drinks
# 5-8    111
# 3-5     91
# 1-3     90
# 8+      86
# 0       26
# NaN      2
# Name: count, dtype: int64

# %%
data["Classes_Missed"].value_counts(dropna=False)
# Out:
# Classes_Missed
# 0      214
# 1       75
# 2       63
# 4+      27
# 3       24
# NaN      3
# Name: count, dtype: int64

# %%
data["Modules_Failed"].value_counts(dropna=False)
# Out:
# Modules_Failed
# 0      263
# 1       58
# 2       31
# 4+      27
# 3       24
# NaN      3
# Name: count, dtype: int64

# %% [markdown]
# # columns unique value

# %%
data["Sex"].unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %%
data["Faculty"].unique()
# Out:
# array(['Arts & Social Sciences', 'Economic & Management Sciences',
#        'AgriSciences', 'Engineering', 'Science',
#        'Medicine and Health Services', 'Law', 'Education', nan],
#       dtype=object)

# %%
data["Accommodation"].unique()
# Out:
# array(['Private accommodation/ stay with family/friends', nan,
#        'Non-private accommodation ie. Res'], dtype=object)

# %%
data["Monthly_Allowance"].unique()
# Out:
# array(['R 4001- R 5000', 'R 7001 - R 8000', 'R 6001 - R 7000',
#        'R 5001 - R 6000', nan, 'R 8000+'], dtype=object)

# %%
data["Study_hours"].unique()
# Out:
# array(['8+', '3-5', '5-8', '1-3', '0', nan], dtype=object)

# %%
data["Alcohol_Drinks"].unique()
# Out:
# array(['8+', '3-5', '5-8', '1-3', '0', nan], dtype=object)

# %%
data["Classes_Missed"].unique()
# Out:
# array(['3', '4+', '2', '1', '0', nan], dtype=object)

# %%
data["Modules_Failed"].unique()
# Out:
# array(['0', '3', '1', nan, '4+', '2'], dtype=object)

# %% [markdown]
# #cleaning the Missing values

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     2
# Matric_GPA              7
# Year_2023              73
# Faculty                 7
# Academic_GPA_2023      86
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          3
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     3
# dtype: int64

# %%
(data.isnull().sum() / len(data) * 100).round(2)
# Out:
# Timestamp               0.00
# Sex                     0.49
# Matric_GPA              1.72
# Year_2023              17.98
# Faculty                 1.72
# Academic_GPA_2023      21.18
# Accommodation           5.67
# Monthly_Allowance       7.64
# Scholarship             1.97
# Study_hours             0.74
# Socialsing              0.49
# Alcohol_Drinks          0.49
# Classes_Missed          0.74
# Modules_Failed          0.74
# Relationship            0.74
# Parent_Approval         0.99
# Parent_Relationship     0.74
# dtype: float64

# %%
data.dtypes
# Out:
# Timestamp               object
# Sex                     object
# Matric_GPA             float64
# Year_2023               object
# Faculty                 object
# Academic_GPA_2023      float64
# Accommodation           object
# Monthly_Allowance       object
# Scholarship             object
# Study_hours             object
# Socialsing              object
# Alcohol_Drinks          object
# Classes_Missed          object
# Modules_Failed          object
# Relationship            object
# Parent_Approval         object
# Parent_Relationship     object
# dtype: object

# %%
data.nunique()
# Out:
# Timestamp              400
# Sex                      2
# Matric_GPA              43
# Year_2023                5
# Faculty                  8
# Academic_GPA_2023       45
# Accommodation            2
# Monthly_Allowance        5
# Scholarship              2
# Study_hours              5
# Socialsing               6
# Alcohol_Drinks           5
# Classes_Missed           5
# Modules_Failed           5
# Relationship             2
# Parent_Approval          2
# Parent_Relationship      4
# dtype: int64

# %%
data.head()
# Out:
#                    Timestamp     Sex  Matric_GPA Year_2023  \
# 0  2024/03/07 5:12:01 pm EET  Female        76.0  2nd Year
# 1  2024/03/07 5:12:08 pm EET    Male        89.0  2nd Year
# 2  2024/03/07 5:12:25 pm EET    Male        76.0  1st Year
# 3  2024/03/07 5:12:28 pm EET    Male        89.0  2nd Year
# 4  2024/03/07 5:13:00 pm EET  Female        74.0  2nd Year
#
#                           Faculty  Academic_GPA_2023  \
# 0          Arts & Social Sciences               72.0
# 1  Economic & Management Sciences               75.0
# 2                    AgriSciences               55.0
# 3                     Engineering               84.0
# 4          Arts & Social Sciences               52.0
#
#                                      Accommodation Monthly_Allowance  \
# 0  Private accommodation/ stay with family/friends    R 4001- R 5000
# 1  Private accommodation/ stay with family/friends   R 7001 - R 8000
# 2  Private accommodation/ stay with family/friends    R 4001- R 5000
# ...

# %% [markdown]
# #  cleaning the timestamp

# %%
data["Timestamp"] = pd.to_datetime(
    data["Timestamp"],
    errors="coerce",
  )
# Out:
# /tmp/ipykernel_5392/2369628077.py:1: FutureWarning: Parsed string "2024/03/07 5:12:01 pm EET" included an un-recognized timezone "EET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   data["Timestamp"] = pd.to_datetime(
# /tmp/ipykernel_5392/2369628077.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Timestamp"] = pd.to_datetime(
# /tmp/ipykernel_5392/2369628077.py:1: FutureWarning: Parsed string "2024/03/07 5:12:08 pm EET" included an un-recognized timezone "EET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   data["Timestamp"] = pd.to_datetime(
# ...

# %%
data["Timestamp"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# #handling missing Sex

# %%
data["Sex"].mode()[0]
# Out:
# 'Male'

# %%
data["Sex"] = data["Sex"].fillna(data["Sex"].mode()[0])

# %%
data["Sex"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #handling Matric GPA

# %%
data["Matric_GPA"].describe()
# Out:
# count    399.000000
# mean      77.989724
# std        7.048618
# min       34.000000
# 25%       74.000000
# 50%       78.000000
# 75%       83.000000
# max       99.000000
# Name: Matric_GPA, dtype: float64

# %%
data["Matric_GPA"] = data["Matric_GPA"].fillna(
    data["Matric_GPA"].median()
)

# %%
data["Matric_GPA"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #cleaning Year_2023

# %%
data["Year_2023"].value_counts(dropna=False)
# Out:
# Year_2023
# 2nd Year        153
# 1st Year        128
# NaN              73
# 3rd Year         40
# 4th Year          7
# Postgraduate      5
# Name: count, dtype: int64

# %% [markdown]
# checking wheather Year_2023 values correspond to missing Academic_GPA_2023

# %%
data[data["Year_2023"].isnull()][
    ["Year_2023","Academic_GPA_2023"]
].head(20)
# Out:
#     Year_2023  Academic_GPA_2023
# 5         NaN                NaN
# 8         NaN                NaN
# 9         NaN                NaN
# 10        NaN                NaN
# 14        NaN                NaN
# 16        NaN                NaN
# 18        NaN                NaN
# 32        NaN                NaN
# 43        NaN                NaN
# 44        NaN                NaN
# 45        NaN                NaN
# 51        NaN                NaN
# 68        NaN                NaN
# 77        NaN                NaN
# 97        NaN                NaN
# 104       NaN                NaN
# 115       NaN                NaN
# 129       NaN                NaN
# 137       NaN                NaN
# 153       NaN                NaN

# %%
data[data["Year_2023"].isna()]["Academic_GPA_2023"].isna().sum()
# Out:
# np.int64(72)

# %%
data["Year_2023"].value_counts(dropna=False)
# Out:
# Year_2023
# 2nd Year        153
# 1st Year        128
# NaN              73
# 3rd Year         40
# 4th Year          7
# Postgraduate      5
# Name: count, dtype: int64

# %%
data[data["Year_2023"].isna()]["Academic_GPA_2023"].isna().sum()
# Out:
# np.int64(72)

# %% [markdown]
# #cleaning Year_2023

# %%
year_mapping = {
    "1st Year": 1,
    "2nd Year": 2,
    "3rd Year": 3,
    "4th Year": 4,
}

# %%
data["Year_2023"] = data["Year_2023"].map(year_mapping)

# %%
data["Year_2023"].value_counts(dropna=False)
# Out:
# Year_2023
# 2.0    153
# 1.0    128
# NaN     78
# 3.0     40
# 4.0      7
# Name: count, dtype: int64

# %% [markdown]
# #cleaning Monthly_Allowance & Study_hours

# %%
data["Monthly_Allowance"].value_counts(dropna=False,ascending=True)
# Out:
# Monthly_Allowance
# R 8000+             27
# R 7001 - R 8000     30
# NaN                 31
# R 6001 - R 7000     58
# R 5001 - R 6000    101
# R 4001- R 5000     159
# Name: count, dtype: int64

# %%
data["Study_hours"].value_counts(dropna=False,ascending=True)
# Out:
# Study_hours
# NaN      3
# 0       20
# 5-8     81
# 1-3     83
# 3-5    105
# 8+     114
# Name: count, dtype: int64

# %% [markdown]
# encoding categories/text by numbers

# %%
allowance_mapping = {
    "R 4001- R 5000": 1,
    "R 5001 - R 6000": 2,
    "R 6001 - R 7000": 3,
    "R 7001 - R 8000": 4,
    "R 8000+": 5
}

data["Monthly_Allowance"] = data["Monthly_Allowance"].map(allowance_mapping)

# %%
study_mapping = {
    "0": 0,
    "1-3": 1,
    "3-5": 2,
    "5-8": 3,
    "8+": 4
}

data["Study_hours"] = data["Study_hours"].map(study_mapping)

# %%
print(data["Monthly_Allowance"].unique())
print(data["Study_hours"].unique())
# Out:
# [ 1.  4.  3.  2. nan  5.]
# [ 4.  2.  3.  1.  0. nan]

# %%
data.dtypes
# Out:
# Timestamp              datetime64[ns]
# Sex                            object
# Matric_GPA                    float64
# Year_2023                     float64
# Faculty                        object
# Academic_GPA_2023             float64
# Accommodation                  object
# Monthly_Allowance             float64
# Scholarship                    object
# Study_hours                   float64
# Socialsing                     object
# Alcohol_Drinks                 object
# Classes_Missed                 object
# Modules_Failed                 object
# Relationship                   object
# Parent_Approval                object
# Parent_Relationship            object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     0
# Matric_GPA              0
# Year_2023              78
# Faculty                 7
# Academic_GPA_2023      86
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          3
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     3
# dtype: int64

# %% [markdown]
# #cleaning Academic_GPA_2023

# %%
data["Academic_GPA_2023"].describe()
# Out:
# count    320.000000
# mean      66.268469
# std        9.147906
# min       30.000000
# 25%       60.000000
# 50%       65.000000
# 75%       73.000000
# max       95.220000
# Name: Academic_GPA_2023, dtype: float64

# %% [markdown]
# checking whether GPA is related to Year_2023

# %%
data.groupby("Year_2023")["Academic_GPA_2023"].agg(
    ["count", "mean", "median"]
)
# Out:
#            count       mean  median
# Year_2023
# 1.0          118  67.169492    65.0
# 2.0          149  65.475906    64.0
# 3.0           40  65.775000    64.0
# 4.0            7  68.714286    65.0

# %%
data.boxplot(
    column="Academic_GPA_2023",
    by="Year_2023"
)
# Out:
# <Axes: title={'center': 'Academic_GPA_2023'}, xlabel='Year_2023'>

# %% [markdown]
# #checking impossible values/negative values in GPA

# %%
data[
    (data["Academic_GPA_2023"] < 0) |
    (data["Academic_GPA_2023"] > 100)
]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Sex, Matric_GPA, Year_2023, Faculty, Academic_GPA_2023, Accommodation, Monthly_Allowance, Scholarship, Study_hours, Socialsing, Alcohol_Drinks, Classes_Missed, Modules_Failed, Relationship, Parent_Approval, Parent_Relationship]
# Index: []

# %% [markdown]
# for Matric_GPA also

# %%
data[
    (data["Matric_GPA"] < 0) |
    (data["Matric_GPA"] > 100)
]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Sex, Matric_GPA, Year_2023, Faculty, Academic_GPA_2023, Accommodation, Monthly_Allowance, Scholarship, Study_hours, Socialsing, Alcohol_Drinks, Classes_Missed, Modules_Failed, Relationship, Parent_Approval, Parent_Relationship]
# Index: []

# %% [markdown]
# #checking whether missing GPA is related to another variable.

# %%
data.groupby("Year_2023")["Academic_GPA_2023"].median()
# Out:
# Year_2023
# 1.0    65.0
# 2.0    64.0
# 3.0    64.0
# 4.0    65.0
# Name: Academic_GPA_2023, dtype: float64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Sex, Matric_GPA, Year_2023, Faculty, Academic_GPA_2023, Accommodation, Monthly_Allowance, Scholarship, Study_hours, Socialsing, Alcohol_Drinks, Classes_Missed, Modules_Failed, Relationship, Parent_Approval, Parent_Relationship]
# Index: []

# %% [markdown]
# #checking duplicate timestamps
#
# also two students could legitimately submit at the same time

# %%
data["Timestamp"].duplicated().sum()
# Out:
# np.int64(6)

# %% [markdown]
# #cleaning whitespacee in text columns

# %%
text_columns = data.select_dtypes(include="object").columns

for col in text_columns:
    data[col] = data[col].str.strip()

# %% [markdown]
# #checking categorical consistency

# %%
categorical_columns = [
    "Sex",
    "Faculty",
    "Accommodation",
    "Scholarship",
    "Socialsing",
    "Relationship",
    "Parent_Approval",
    "Parent_Relationship"
]

for col in categorical_columns:
    print("\n", col)
    print(data[col].value_counts(dropna=False))
# Out:
#  Sex
# Sex
# Male      218
# Female    188
# Name: count, dtype: int64
#
#  Faculty
# Faculty
# Economic & Management Sciences    211
# Science                            56
# Arts & Social Sciences             47
# Engineering                        37
# AgriSciences                       22
# Medicine and Health Services       10
# Law                                10
# NaN                                 7
# Education                           6
# Name: count, dtype: int64
#
#  Accommodation
# Accommodation
# Private accommodation/ stay with family/friends    335
# Non-private accommodation ie. Res                   48
# NaN                                                 23
# Name: count, dtype: int64
#
#  Scholarship
# Scholarship
# No                     352
# Yes (NSFAS, etc...)     46
# NaN                      8
# Name: count, dtype: int64
#
#  Socialsing
# Socialsing
# Only weekends    113
# 1                108
# 2                 87
# 3                 63
# ...

# %% [markdown]
# #checking the whole dataset again

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            406 non-null    datetime64[ns]
#  1   Sex                  406 non-null    object
#  2   Matric_GPA           406 non-null    float64
#  3   Year_2023            328 non-null    float64
#  4   Faculty              399 non-null    object
#  5   Academic_GPA_2023    320 non-null    float64
#  6   Accommodation        383 non-null    object
#  7   Monthly_Allowance    375 non-null    float64
#  8   Scholarship          398 non-null    object
#  9   Study_hours          403 non-null    float64
#  10  Socialsing           404 non-null    object
#  11  Alcohol_Drinks       404 non-null    object
#  12  Classes_Missed       403 non-null    object
#  13  Modules_Failed       403 non-null    object
#  14  Relationship         403 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     0
# Matric_GPA              0
# Year_2023              78
# Faculty                 7
# Academic_GPA_2023      86
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          3
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     3
# dtype: int64

# %%
missing_percent = (
    data.isnull().sum() / len(data) * 100
).round(2)

missing_percent
# Out:
# Timestamp               0.00
# Sex                     0.00
# Matric_GPA              0.00
# Year_2023              19.21
# Faculty                 1.72
# Academic_GPA_2023      21.18
# Accommodation           5.67
# Monthly_Allowance       7.64
# Scholarship             1.97
# Study_hours             0.74
# Socialsing              0.49
# Alcohol_Drinks          0.49
# Classes_Missed          0.74
# Modules_Failed          0.74
# Relationship            0.74
# Parent_Approval         0.99
# Parent_Relationship     0.74
# dtype: float64

# %%
data.head()
# Out:
#             Timestamp     Sex  Matric_GPA  Year_2023  \
# 0 2024-03-07 17:12:01  Female        76.0        2.0
# 1 2024-03-07 17:12:08    Male        89.0        2.0
# 2 2024-03-07 17:12:25    Male        76.0        1.0
# 3 2024-03-07 17:12:28    Male        89.0        2.0
# 4 2024-03-07 17:13:00  Female        74.0        2.0
#
#                           Faculty  Academic_GPA_2023  \
# 0          Arts & Social Sciences               72.0
# 1  Economic & Management Sciences               75.0
# 2                    AgriSciences               55.0
# 3                     Engineering               84.0
# 4          Arts & Social Sciences               52.0
#
#                                      Accommodation  Monthly_Allowance  \
# 0  Private accommodation/ stay with family/friends                1.0
# 1  Private accommodation/ stay with family/friends                4.0
# 2  Private accommodation/ stay with family/friends                1.0
# ...

# %% [markdown]
# #checking Alcohol_Drinks column

# %%
data["Alcohol_Drinks"].value_counts(dropna=False,ascending=True)
# Out:
# Alcohol_Drinks
# NaN      2
# 0       26
# 8+      86
# 1-3     90
# 3-5     91
# 5-8    111
# Name: count, dtype: int64

# %% [markdown]
# #checking Classes_Missed

# %%
data["Classes_Missed"].value_counts(dropna=False,ascending=True)
# Out:
# Classes_Missed
# NaN      3
# 3       24
# 4+      27
# 2       63
# 1       75
# 0      214
# Name: count, dtype: int64

# %% [markdown]
# #checking Modules_Failed

# %%
data["Modules_Failed"].value_counts(dropna=False)
# Out:
# Modules_Failed
# 0      263
# 1       58
# 2       31
# 4+      27
# 3       24
# NaN      3
# Name: count, dtype: int64

# %% [markdown]
# creating mapping for Modules_Failed

# %%
data["Modules_Failed"].unique()
# Out:
# array(['0', '3', '1', nan, '4+', '2'], dtype=object)

# %%
modules_mapping = {
    "0": 0,
    "1": 1,
    "2": 2,
    "3": 3,
    "4+": 4       #here encoding 4+ with 4 means (more than 4 modules)
}

# %%
data["Modules_Failed"] = data["Modules_Failed"].map(modules_mapping)

# %%
data["Modules_Failed"].value_counts(dropna=False)
# Out:
# Modules_Failed
# 0.0    263
# 1.0     58
# 2.0     31
# 4.0     27
# 3.0     24
# NaN      3
# Name: count, dtype: int64

# %%
data["Modules_Failed"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #cleaning Classes_Missed

# %%
data["Classes_Missed"].unique()
# Out:
# array(['3', '4+', '2', '1', '0', nan], dtype=object)

# %% [markdown]
# mapping/encoding

# %%
classes_mapping = {
    "0": 0,
    "1": 1,
    "2": 2,
    "3": 3,
    "4+": 4   #(encoding 4+ with 4 i.e. more than 4 classes)
}

# %%
data["Classes_Missed"] = data["Classes_Missed"].map(classes_mapping)

# %%
data["Classes_Missed"].value_counts(dropna=False)
# Out:
# Classes_Missed
# 0.0    214
# 1.0     75
# 2.0     63
# 4.0     27
# 3.0     24
# NaN      3
# Name: count, dtype: int64

# %% [markdown]
# #checking Relationship

# %%
Relationship_mapping = {
    "No" : 0,
    "Yes" : 1
}

data["Relationship"] = data["Relationship"].map(Relationship_mapping)

# %% [markdown]
# #checking Parent_Approval

# %%
data["Parent_Approval"].value_counts(dropna=False)
# Out:
# Parent_Approval
# Yes    353
# No      49
# NaN      4
# Name: count, dtype: int64

# %%
approval_mapping = {
    "No": 0,
    "Yes": 1
}

data["Parent_Approval"] = data["Parent_Approval"].map(
    approval_mapping
)

# %% [markdown]
# #checking Parent_Relationship

# %%
data["Parent_Relationship"].value_counts(dropna=False)
# Out:
# Parent_Relationship
# Very close    269
# Close          97
# Fair           35
# NaN             3
# Distant         2
# Name: count, dtype: int64

# %%
parent_mapping = {
    "Distant": 0,
    "Fair": 1,
    "Close": 2,
    "Very close": 3
}

# %%
data["Parent_Relationship"] = data["Parent_Relationship"].map(
    parent_mapping
)

# %%
data["Parent_Relationship"].value_counts(dropna=False)
# Out:
# Parent_Relationship
# 3.0    269
# 2.0     97
# 1.0     35
# NaN      3
# 0.0      2
# Name: count, dtype: int64

# %% [markdown]
# #checking Socialsing

# %%
data["Socialsing"].value_counts(dropna=False)
# Out:
# Socialsing
# Only weekends    113
# 1                108
# 2                 87
# 3                 63
# 0                 17
# 4+                16
# NaN                2
# Name: count, dtype: int64

# %%
data["Socialsing"].unique()
# Out:
# array(['Only weekends', '2', '3', '4+', '1', '0', nan], dtype=object)

# %%
data["Socialsing"].isnull().sum()
# Out:
# np.int64(2)

# %%
data["Socialsing"].mode()
# Out:
# 0    Only weekends
# Name: Socialsing, dtype: object

# %%
data["Socialsing"].value_counts(normalize=True, dropna=False) * 100
# Out:
# Socialsing
# Only weekends    27.832512
# 1                26.600985
# 2                21.428571
# 3                15.517241
# 0                 4.187192
# 4+                3.940887
# NaN               0.492611
# Name: proportion, dtype: float64

# %% [markdown]
# #checking the other columns

# %%
data["Alcohol_Drinks"].value_counts(dropna=False)
# Out:
# Alcohol_Drinks
# 5-8    111
# 3-5     91
# 1-3     90
# 8+      86
# 0       26
# NaN      2
# Name: count, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (406, 17)

# %% [markdown]
# saving current cleaned version to a backup data

# %%
backup_data = data.copy()

# %%
data.to_csv("student_cleaning_progress.csv",index=False)

# %% [markdown]
# #for Alcohol_Drinks

# %%
data["Alcohol_Drinks"].value_counts(dropna=False)
# Out:
# Alcohol_Drinks
# 5-8    111
# 3-5     91
# 1-3     90
# 8+      86
# 0       26
# NaN      2
# Name: count, dtype: int64

# %%
alcohol_mapping = {
    "0": 0,
    "1-3": 1,
    "3-5": 2,
    "5-8": 3,
    "8+": 4
}
data["Alcohol_Drinks"] = data["Alcohol_Drinks"].map(alcohol_mapping)

# %%
data["Alcohol_Drinks"].value_counts(dropna=False)
# Out:
# Alcohol_Drinks
# 3.0    111
# 2.0     91
# 1.0     90
# 4.0     86
# 0.0     26
# NaN      2
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            406 non-null    datetime64[ns]
#  1   Sex                  406 non-null    object
#  2   Matric_GPA           406 non-null    float64
#  3   Year_2023            328 non-null    float64
#  4   Faculty              399 non-null    object
#  5   Academic_GPA_2023    320 non-null    float64
#  6   Accommodation        383 non-null    object
#  7   Monthly_Allowance    375 non-null    float64
#  8   Scholarship          398 non-null    object
#  9   Study_hours          403 non-null    float64
#  10  Socialsing           404 non-null    object
#  11  Alcohol_Drinks       404 non-null    float64
#  12  Classes_Missed       403 non-null    float64
#  13  Modules_Failed       403 non-null    float64
#  14  Relationship         403 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     0
# Matric_GPA              0
# Year_2023              78
# Faculty                 7
# Academic_GPA_2023      86
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          3
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     3
# dtype: int64

# %% [markdown]
# # filling missing values for Classes_Missed

# %%
data["Modules_Failed"].median()
# Out:
# 0.0

# %%
data["Modules_Failed"] = data["Modules_Failed"].fillna(
    data["Modules_Failed"].median()
)

# %%
data["Modules_Failed"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #filling missing values for Parent_Relationship

# %%
data["Parent_Relationship"].mode()
# Out:
# 0    3.0
# Name: Parent_Relationship, dtype: float64

# %%
data["Parent_Relationship"] = data["Parent_Relationship"].fillna(
    data["Parent_Relationship"].mode()[0]
)

# %%
data["Parent_Relationship"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #checking all missing values

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     0
# Matric_GPA              0
# Year_2023              78
# Faculty                 7
# Academic_GPA_2023      86
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          0
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     0
# dtype: int64

# %%
missing = data.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)

missing
# Out:
# Academic_GPA_2023    86
# Year_2023            78
# Monthly_Allowance    31
# Accommodation        23
# Scholarship           8
# Faculty               7
# Parent_Approval       4
# Study_hours           3
# Relationship          3
# Classes_Missed        3
# Socialsing            2
# Alcohol_Drinks        2
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
missing.plot(
    kind="bar",
    figsize=(10,5),
    title="Missing Values by Column"
)

plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Filling missing values in Academic_GPA_2023

# %%
data["Academic_GPA_2023"].plot(
    kind="hist",
    bins=15,
    figsize=(8,5),
    title="Distribution of Academic GPA 2023"
)

plt.xlabel("Academic GPA")
plt.ylabel("Frequency")
plt.show()

# %%
data.boxplot(
    column="Academic_GPA_2023",
    figsize=(6,5)
)

plt.title("Academic GPA 2023 - Boxplot")
plt.ylabel("GPA")
plt.show()

# %%
gpa_mean = data["Academic_GPA_2023"].mean()
gpa_mean
# Out:
# np.float64(66.26846875)

# %%
gpa_median = data["Academic_GPA_2023"].median()
gpa_median
# Out:
# 65.0

# %%
print("Mean:", gpa_mean)
print("Median:", gpa_median)
# Out:
# Mean: 66.26846875
# Median: 65.0

# %%
plt.figure(figsize=(8,5))

plt.hist(data["Academic_GPA_2023"].dropna(), bins=15)

plt.axvline(
    gpa_mean,
    linestyle="--",
    label="Mean",
    color="red"
)

plt.axvline(
    gpa_median,
    linestyle="--",
    label="Median",
    color="green"
)

plt.title("Academic GPA: Mean vs Median")
plt.xlabel("GPA")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# #checking GPA by academic year

# %%
data.groupby("Year_2023")["Academic_GPA_2023"].median()
# Out:
# Year_2023
# 1.0    65.0
# 2.0    64.0
# 3.0    64.0
# 4.0    65.0
# Name: Academic_GPA_2023, dtype: float64

# %%
data.groupby("Year_2023")["Academic_GPA_2023"].median().plot(
    kind="bar",
    figsize=(7,5),
    title="Median GPA by Academic Year"
)

plt.xlabel("Academic Year")
plt.ylabel("Median GPA")
plt.show()

# %% [markdown]
# #checking GPA vs Mtric GPA

# %%
data.plot(
    x="Matric_GPA",
    y="Academic_GPA_2023",
    kind="scatter",
    figsize=(8,5),
    title="Matric GPA vs Academic GPA 2023"
)

plt.xlabel("Matric GPA")
plt.ylabel("Academic GPA 2023")
plt.show()

# %% [markdown]
# #calculate the correlation

# %%
data[
    ["Matric_GPA", "Academic_GPA_2023"]
].corr()
# Out:
#                    Matric_GPA  Academic_GPA_2023
# Matric_GPA           1.000000           0.298824
# Academic_GPA_2023    0.298824           1.000000

# %% [markdown]
# group-based median

# %%
data["Academic_GPA_2023"] = data.groupby(
    "Year_2023"
)["Academic_GPA_2023"].transform(
    lambda x: x.fillna(x.median())
)

# %%
data["Academic_GPA_2023"].isnull().sum()
# Out:
# np.int64(78)

# %% [markdown]
# #filling the remaining with overall median

# %%
data["Academic_GPA_2023"] = data[
    "Academic_GPA_2023"
].fillna(
    data["Academic_GPA_2023"].median()
)

# %%
data["Academic_GPA_2023"].isnull().sum()
# Out:
# np.int64(0)

# %%
data["Academic_GPA_2023"].plot(
    kind="hist",
    bins=15,
    figsize=(8,5),
    title="Academic GPA After Missing Value Treatment"
)

plt.xlabel("Academic GPA")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #checking the complete missing value

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     0
# Matric_GPA              0
# Year_2023              78
# Faculty                 7
# Academic_GPA_2023       0
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          0
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     0
# dtype: int64

# %%
(data.isnull().sum() / len(data) * 100).round(2)
# Out:
# Timestamp               0.00
# Sex                     0.00
# Matric_GPA              0.00
# Year_2023              19.21
# Faculty                 1.72
# Academic_GPA_2023       0.00
# Accommodation           5.67
# Monthly_Allowance       7.64
# Scholarship             1.97
# Study_hours             0.74
# Socialsing              0.49
# Alcohol_Drinks          0.49
# Classes_Missed          0.74
# Modules_Failed          0.00
# Relationship            0.74
# Parent_Approval         0.99
# Parent_Relationship     0.00
# dtype: float64

# %% [markdown]
# #checking outliners

# %%
data["Matric_GPA"].plot(
    kind="box",
    figsize=(7,5),
    title="Matric GPA - Boxplot"
)

plt.ylabel("GPA")
plt.show()

# %%
data["Matric_GPA"].plot(
    kind="hist",
    bins=15,
    figsize=(8,5),
    title="Distribution of Matric GPA"
)

plt.xlabel("Matric GPA")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #calculating IQR

# %%
Q1 = data["Matric_GPA"].quantile(0.25)
Q1
# Out:
# np.float64(74.0)

# %%
Q3 = data["Matric_GPA"].quantile(0.75)
Q3
# Out:
# np.float64(83.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(9.0)

# %% [markdown]
# #lower boundary

# %%
lower_bound = Q1 - 1.5 * IQR
lower_bound
# Out:
# np.float64(60.5)

# %% [markdown]
# #upper boundary

# %%
upper_bound = Q3 + 1.5 * IQR
upper_bound
# Out:
# np.float64(96.5)

# %%
matric_outliers = data[
    (data["Matric_GPA"] < lower_bound) |
    (data["Matric_GPA"] > upper_bound)
]

# %%
matric_outliers[["Matric_GPA"]]
# Out:
#      Matric_GPA
# 38        99.00
# 54        98.00
# 73        98.33
# 203       60.00
# 254       34.00
# 268       60.00
# 335       55.00
# 358       60.00

# %%
len(matric_outliers)
# Out:
# 8

# %%
outlier_percentage = (
    len(matric_outliers) / data["Matric_GPA"].notna().sum()
) * 100

print(outlier_percentage)
# Out:
# 1.9704433497536946

# %%
matric_outliers
# Out:
#               Timestamp     Sex  Matric_GPA  Year_2023  \
# 38  2024-03-07 17:20:31    Male       99.00        2.0
# 54  2024-03-07 17:25:13    Male       98.00        1.0
# 73  2024-03-07 17:39:33  Female       98.33        2.0
# 203 2024-03-07 20:56:01  Female       60.00        1.0
# 254 2024-03-07 23:19:54    Male       34.00        NaN
# 268 2024-03-07 23:31:34    Male       60.00        1.0
# 335 2024-03-08 17:50:07  Female       55.00        2.0
# 358 2024-03-11 14:06:41    Male       60.00        2.0
#
#                             Faculty  Academic_GPA_2023  \
# 38   Economic & Management Sciences              90.00
# 54                      Engineering              89.00
# 73   Economic & Management Sciences              95.22
# 203  Economic & Management Sciences              65.00
# 254  Economic & Management Sciences              65.00
# 268  Economic & Management Sciences              75.00
# 335  Economic & Management Sciences              61.00
# ...

# %% [markdown]
# #for Academic GPA

# %%
data["Academic_GPA_2023"]
# Out:
# 0      72.0
# 1      75.0
# 2      55.0
# 3      84.0
# 4      52.0
#        ...
# 401    65.0
# 402    58.0
# 403    65.0
# 404    65.0
# 405    63.0
# Name: Academic_GPA_2023, Length: 406, dtype: float64

# %%
data["Academic_GPA_2023"].plot(
    kind="box",
    figsize=(7,5),
    title="Academic GPA 2023 - Boxplot"
)

plt.ylabel("GPA")
plt.show()

# %%
Q1_gpa = data["Academic_GPA_2023"].quantile(0.25)
Q3_gpa = data["Academic_GPA_2023"].quantile(0.75)

IQR_gpa = Q3_gpa - Q1_gpa

lower_gpa = Q1_gpa - 1.5 * IQR_gpa
upper_gpa = Q3_gpa + 1.5 * IQR_gpa

print("Q1:", Q1_gpa)
print("Q3:", Q3_gpa)
print("IQR:", IQR_gpa)
print("Lower:", lower_gpa)
print("Upper:", upper_gpa)
# Out:
# Q1: 61.0
# Q3: 70.0
# IQR: 9.0
# Lower: 47.5
# Upper: 83.5

# %%
gpa_outliers = data[
    (data["Academic_GPA_2023"] < lower_gpa) |
    (data["Academic_GPA_2023"] > upper_gpa)
]

# %%
print("Number of outliers:", len(gpa_outliers))
# Out:
# Number of outliers: 14

# %%
gpa_outliers[["Matric_GPA", "Academic_GPA_2023"]]
# Out:
#      Matric_GPA  Academic_GPA_2023
# 3         89.00              84.00
# 38        99.00              90.00
# 54        98.00              89.00
# 73        98.33              95.22
# 85        85.00              84.00
# 116       85.00              88.00
# 195       92.00              88.00
# 205       83.00              84.00
# 237       84.00              92.00
# 243       95.00              87.60
# 303       67.00              30.00
# 310       75.00              89.00
# 346       86.00              85.00
# 353       78.00              85.00

# %%
data["Matric_GPA"].describe()
# Out:
# count    406.000000
# mean      77.989901
# std        6.987439
# min       34.000000
# 25%       74.000000
# 50%       78.000000
# 75%       83.000000
# max       99.000000
# Name: Matric_GPA, dtype: float64

# %%
print("Matric lower:", lower_bound)
print("Matric upper:", upper_bound)
print("Matric outliers:", len(matric_outliers))
# Out:
# Matric lower: 60.5
# Matric upper: 96.5
# Matric outliers: 8

# %%
print("Academic GPA lower:", lower_gpa)
print("Academic GPA upper:", upper_gpa)
print("Academic GPA outliers:", len(gpa_outliers))
# Out:
# Academic GPA lower: 47.5
# Academic GPA upper: 83.5
# Academic GPA outliers: 14

# %% [markdown]
# #visualization

# %%
data["Sex"].value_counts(dropna=False)
# Out:
# Sex
# Male      218
# Female    188
# Name: count, dtype: int64

# %%
data["Sex"].value_counts().plot(
    kind="bar",
    figsize=(6,5),
    title="Students by Sex"
)

plt.xlabel("Sex")
plt.ylabel("Number of Students")
plt.show()

# %%
data["Sex"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6),
    title="Gender Distribution"
)

plt.ylabel("")
plt.show()

# %%
data["Faculty"].value_counts().plot(
    kind="bar",
    figsize=(10,5),
    title="Students by Faculty"
)

plt.xlabel("Faculty")
plt.ylabel("Number of Students")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
data["Monthly_Allowance"].value_counts().sort_index().plot(
    kind="bar",
    figsize=(7,5),
    title="Monthly Allowance Category"
)

plt.xlabel("Allowance Category")
plt.ylabel("Number of Students")
plt.show()

# %%
data["Study_hours"].value_counts().sort_index().plot(
    kind="bar",
    figsize=(7,5),
    title="Study Hours Category"
)

plt.xlabel("Study Hours Category")
plt.ylabel("Number of Students")
plt.show()

# %%
data["Alcohol_Drinks"].value_counts().sort_index().plot(
    kind="bar",
    figsize=(7,5),
    title="Alcohol Consumption Category"
)

plt.xlabel("Alcohol Category")
plt.ylabel("Number of Students")
plt.show()

# %%
data["Classes_Missed"].value_counts().sort_index().plot(
    kind="bar",
    figsize=(7,5),
    title="Classes Missed"
)

plt.xlabel("Classes Missed")
plt.ylabel("Number of Students")
plt.show()

# %%
data["Modules_Failed"].value_counts().sort_index().plot(
    kind="bar",
    figsize=(7,5),
    title="Modules Failed"
)

plt.xlabel("Modules Failed")
plt.ylabel("Number of Students")
plt.show()

# %%
data.groupby("Study_hours")["Academic_GPA_2023"].mean().plot(
    kind="bar",
    figsize=(7,5),
    title="Average GPA by Study Hours"
)

plt.xlabel("Study Hours Category")
plt.ylabel("Average Academic GPA")
plt.show()

# %%
data.groupby("Modules_Failed")["Academic_GPA_2023"].mean().plot(
    kind="bar",
    figsize=(7,5),
    title="Average GPA by Modules Failed"
)

plt.xlabel("Modules Failed")
plt.ylabel("Average Academic GPA")
plt.show()

# %%
data.groupby("Classes_Missed")["Academic_GPA_2023"].mean().plot(
    kind="bar",
    figsize=(7,5),
    title="Average GPA by Classes Missed"
)

plt.xlabel("Classes Missed")
plt.ylabel("Average Academic GPA")
plt.show()

# %%
numeric_data = data.select_dtypes(include="number")

correlation = numeric_data.corr()

correlation
# Out:
#                      Matric_GPA  Year_2023  Academic_GPA_2023  \
# Matric_GPA             1.000000   0.142070           0.253576
# Year_2023              0.142070   1.000000          -0.040146
# Academic_GPA_2023      0.253576  -0.040146           1.000000
# Monthly_Allowance      0.018349   0.100635           0.063516
# Study_hours            0.202265   0.195002           0.024012
# Alcohol_Drinks        -0.105974   0.015285          -0.063022
# Classes_Missed         0.028453  -0.082190          -0.090446
# Modules_Failed        -0.107578   0.171565          -0.389108
# Relationship           0.005597   0.027008           0.057992
# Parent_Approval        0.078934   0.054173           0.089126
# Parent_Relationship   -0.041027  -0.026316          -0.036231
#
#                      Monthly_Allowance  Study_hours  Alcohol_Drinks  \
# Matric_GPA                    0.018349     0.202265       -0.105974
# Year_2023                     0.100635     0.195002        0.015285
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,7))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()

# %%
gpa_corr = correlation["Academic_GPA_2023"].sort_values(
    ascending=False
)

gpa_corr
# Out:
# Academic_GPA_2023      1.000000
# Matric_GPA             0.253576
# Parent_Approval        0.089126
# Monthly_Allowance      0.063516
# Relationship           0.057992
# Study_hours            0.024012
# Parent_Relationship   -0.036231
# Year_2023             -0.040146
# Alcohol_Drinks        -0.063022
# Classes_Missed        -0.090446
# Modules_Failed        -0.389108
# Name: Academic_GPA_2023, dtype: float64

# %%
data[["Matric_GPA", "Academic_GPA_2023"]].plot(
    kind="box",
    figsize=(7,5),
    title="Matric GPA vs Academic GPA"
)

plt.ylabel("GPA")
plt.show()

# %% [markdown]
# #final cleaning & encoding

# %%
data.columns
# Out:
# Index(['Timestamp', 'Sex', 'Matric_GPA', 'Year_2023', 'Faculty',
#        'Academic_GPA_2023', 'Accommodation', 'Monthly_Allowance',
#        'Scholarship', 'Study_hours', 'Socialsing', 'Alcohol_Drinks',
#        'Classes_Missed', 'Modules_Failed', 'Relationship', 'Parent_Approval',
#        'Parent_Relationship'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Timestamp               0
# Sex                     0
# Matric_GPA              0
# Year_2023              78
# Faculty                 7
# Academic_GPA_2023       0
# Accommodation          23
# Monthly_Allowance      31
# Scholarship             8
# Study_hours             3
# Socialsing              2
# Alcohol_Drinks          2
# Classes_Missed          3
# Modules_Failed          0
# Relationship            3
# Parent_Approval         4
# Parent_Relationship     0
# dtype: int64

# %%
(data.isnull().sum() / len(data) * 100).round(2)
# Out:
# Timestamp               0.00
# Sex                     0.00
# Matric_GPA              0.00
# Year_2023              19.21
# Faculty                 1.72
# Academic_GPA_2023       0.00
# Accommodation           5.67
# Monthly_Allowance       7.64
# Scholarship             1.97
# Study_hours             0.74
# Socialsing              0.49
# Alcohol_Drinks          0.49
# Classes_Missed          0.74
# Modules_Failed          0.00
# Relationship            0.74
# Parent_Approval         0.99
# Parent_Relationship     0.00
# dtype: float64

# %%
data["Year_2023"].value_counts(dropna=False)
# Out:
# Year_2023
# 2.0    153
# 1.0    128
# NaN     78
# 3.0     40
# 4.0      7
# Name: count, dtype: int64

# %%
data["Study_hours"].value_counts(dropna=False).sort_index()
# Out:
# Study_hours
# 0.0     20
# 1.0     83
# 2.0    105
# 3.0     81
# 4.0    114
# NaN      3
# Name: count, dtype: int64

# %%
data["Monthly_Allowance"].value_counts(dropna=False).sort_index()
# Out:
# Monthly_Allowance
# 1.0    159
# 2.0    101
# 3.0     58
# 4.0     30
# 5.0     27
# NaN     31
# Name: count, dtype: int64

# %%
data["Scholarship"].value_counts(dropna=False)
# Out:
# Scholarship
# No                     352
# Yes (NSFAS, etc...)     46
# NaN                      8
# Name: count, dtype: int64

# %%
scholarship_mapping = {
    "No": 0,
    "Yes(NSFAS,etc...)": 1
}

data["Scholarship"] = data["Scholarship"].map(
    scholarship_mapping
)

# %%
data["Relationship"].value_counts(dropna=False)
# Out:
# Relationship
# 0.0    239
# 1.0    164
# NaN      3
# Name: count, dtype: int64

# %%
data["Parent_Approval"].value_counts(dropna=False)
# Out:
# Parent_Approval
# 1.0    353
# 0.0     49
# NaN      4
# Name: count, dtype: int64

# %%
data = pd.get_dummies(
    data,
    columns=["Sex", "Faculty", "Accommodation"],
    drop_first=True
)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Matric_GPA', 'Year_2023', 'Academic_GPA_2023',
#        'Monthly_Allowance', 'Scholarship', 'Study_hours', 'Socialsing',
#        'Alcohol_Drinks', 'Classes_Missed', 'Modules_Failed', 'Relationship',
#        'Parent_Approval', 'Parent_Relationship', 'Sex_Male',
#        'Faculty_Arts & Social Sciences',
#        'Faculty_Economic & Management Sciences', 'Faculty_Education',
#        'Faculty_Engineering', 'Faculty_Law',
#        'Faculty_Medicine and Health Services', 'Faculty_Science',
#        'Accommodation_Private accommodation/ stay with family/friends'],
#       dtype='object')

# %%
data.head()
# Out:
#             Timestamp  Matric_GPA  Year_2023  Academic_GPA_2023  \
# 0 2024-03-07 17:12:01        76.0        2.0               72.0
# 1 2024-03-07 17:12:08        89.0        2.0               75.0
# 2 2024-03-07 17:12:25        76.0        1.0               55.0
# 3 2024-03-07 17:12:28        89.0        2.0               84.0
# 4 2024-03-07 17:13:00        74.0        2.0               52.0
#
#    Monthly_Allowance  Scholarship  Study_hours     Socialsing  Alcohol_Drinks  \
# 0                1.0          0.0          4.0  Only weekends             4.0
# 1                4.0          NaN          4.0  Only weekends             2.0
# 2                1.0          0.0          2.0              2             4.0
# 3                3.0          0.0          2.0              3             4.0
# 4                1.0          0.0          2.0  Only weekends             3.0
#
#    Classes_Missed  ...  Parent_Relationship  Sex_Male  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 23 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Timestamp                                                      406 non-null    datetime64[ns]
#  1   Matric_GPA                                                     406 non-null    float64
#  2   Year_2023                                                      328 non-null    float64
#  3   Academic_GPA_2023                                              406 non-null    float64
#  4   Monthly_Allowance                                              375 non-null    float64
#  5   Scholarship                                                    352 non-null    float64
#  6   Study_hours                                                    403 non-null    float64
# ...

# %%
data.select_dtypes(include="object").columns
# Out:
# Index(['Socialsing'], dtype='object')

# %%
print("Duplicate rows:", data.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print("Rows:", data.shape[0])
print("Columns:", data.shape[1])
# Out:
# Rows: 406
# Columns: 23

# %%
data.select_dtypes(include="object").columns
# Out:
# Index(['Socialsing'], dtype='object')

# %%
data["Timestamp"].head()
# Out:
# 0   2024-03-07 17:12:01
# 1   2024-03-07 17:12:08
# 2   2024-03-07 17:12:25
# 3   2024-03-07 17:12:28
# 4   2024-03-07 17:13:00
# Name: Timestamp, dtype: datetime64[ns]

# %%
data = data.drop(columns=["Timestamp"])

# %%
data["Socialsing"].value_counts(dropna=False)
# Out:
# Socialsing
# Only weekends    113
# 1                108
# 2                 87
# 3                 63
# 0                 17
# 4+                16
# NaN                2
# Name: count, dtype: int64

# %%
data["Socialsing"].value_counts(dropna=False).plot(
    kind="bar",
    figsize=(8,5),
    title="Socialising Frequency"
)

plt.xlabel("Socialising Category")
plt.ylabel("Number of Students")
plt.xticks(rotation=30)
plt.show()

# %%
data[["Matric_GPA", "Academic_GPA_2023"]].plot(
    kind="hist",
    bins=15,
    alpha=0.7,
    figsize=(9,5),
    title="GPA Distributions"
)

plt.xlabel("GPA")
plt.ylabel("Frequency")
plt.show()

# %%
data[["Matric_GPA", "Academic_GPA_2023"]].plot(
    kind="box",
    figsize=(8,5),
    title="GPA Outlier Check"
)

plt.ylabel("GPA")
plt.show()

# %%
print("Matric GPA:")
print("Min:", data["Matric_GPA"].min())
print("Max:", data["Matric_GPA"].max())

print("\nAcademic GPA:")
print("Min:", data["Academic_GPA_2023"].min())
print("Max:", data["Academic_GPA_2023"].max())
# Out:
# Matric GPA:
# Min: 34.0
# Max: 99.0
#
# Academic GPA:
# Min: 30.0
# Max: 95.22

# %%
invalid_gpa = data[
    (data["Matric_GPA"] < 0) |
    (data["Matric_GPA"] > 100) |
    (data["Academic_GPA_2023"] < 0) |
    (data["Academic_GPA_2023"] > 100)
]

invalid_gpa
# Out:
# Empty DataFrame
# Columns: [Matric_GPA, Year_2023, Academic_GPA_2023, Monthly_Allowance, Scholarship, Study_hours, Socialsing, Alcohol_Drinks, Classes_Missed, Modules_Failed, Relationship, Parent_Approval, Parent_Relationship, Sex_Male, Faculty_Arts & Social Sciences, Faculty_Economic & Management Sciences, Faculty_Education, Faculty_Engineering, Faculty_Law, Faculty_Medicine and Health Services, Faculty_Science, Accommodation_Private accommodation/ stay with family/friends]
# Index: []
#
# [0 rows x 22 columns]

# %%
numeric_data = data.select_dtypes(include="number")

correlation = numeric_data.corr()

# %%
correlation
# Out:
#                      Matric_GPA  Year_2023  Academic_GPA_2023  \
# Matric_GPA             1.000000   0.142070           0.253576
# Year_2023              0.142070   1.000000          -0.040146
# Academic_GPA_2023      0.253576  -0.040146           1.000000
# Monthly_Allowance      0.018349   0.100635           0.063516
# Scholarship                 NaN        NaN                NaN
# Study_hours            0.202265   0.195002           0.024012
# Alcohol_Drinks        -0.105974   0.015285          -0.063022
# Classes_Missed         0.028453  -0.082190          -0.090446
# Modules_Failed        -0.107578   0.171565          -0.389108
# Relationship           0.005597   0.027008           0.057992
# Parent_Approval        0.078934   0.054173           0.089126
# Parent_Relationship   -0.041027  -0.026316          -0.036231
#
#                      Monthly_Allowance  Scholarship  Study_hours  \
# Matric_GPA                    0.018349          NaN     0.202265
# ...

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    correlation,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Final Correlation Heatmap")
plt.show()

# %%
correlation["Academic_GPA_2023"].sort_values(
    ascending=False
)
# Out:
# Academic_GPA_2023      1.000000
# Matric_GPA             0.253576
# Parent_Approval        0.089126
# Monthly_Allowance      0.063516
# Relationship           0.057992
# Study_hours            0.024012
# Parent_Relationship   -0.036231
# Year_2023             -0.040146
# Alcohol_Drinks        -0.063022
# Classes_Missed        -0.090446
# Modules_Failed        -0.389108
# Scholarship                 NaN
# Name: Academic_GPA_2023, dtype: float64

# %%
plt.figure(figsize=(7,5))

sns.boxplot(
    x="Modules_Failed",
    y="Academic_GPA_2023",
    data=data
)

plt.title("Academic GPA vs Modules Failed")
plt.xlabel("Modules Failed")
plt.ylabel("Academic GPA")
plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(
    x="Classes_Missed",
    y="Academic_GPA_2023",
    data=data
)

plt.title("Academic GPA vs Classes Missed")
plt.xlabel("Classes Missed")
plt.ylabel("Academic GPA")
plt.show()

# %%
backup_data = data.copy()

# %%
raw_data = pd.read_csv('/content/drive/MyDrive/data file/survey_student.csv')

# %%
raw_data
# Out:
#                       Timestamp Your Sex?  \
# 0     2024/03/07 5:12:01 pm EET    Female
# 1     2024/03/07 5:12:08 pm EET      Male
# 2     2024/03/07 5:12:25 pm EET      Male
# 3     2024/03/07 5:12:28 pm EET      Male
# 4     2024/03/07 5:13:00 pm EET    Female
# ..                          ...       ...
# 401  2024/03/12 11:05:33 am EET    Female
# 402   2024/03/12 3:26:14 pm EET    Female
# 403  2024/03/13 10:32:19 pm EET    Female
# 404  2024/03/13 10:32:27 pm EET      Male
# 405  2024/03/16 10:30:36 pm EET    Female
#
#      Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                          76.0
# 1                                          89.0
# 2                                          76.0
# 3                                          89.0
# 4                                          74.0
# ..                                          ...
# 401                                        74.0
# 402                                        73.0
# ...

# %%
print("Raw shape:", raw_data.shape)
print("Cleaned shape:", data.shape)
# Out:
# Raw shape: (406, 17)
# Cleaned shape: (406, 22)

# %%
print(data.isnull().sum())
# Out:
# Matric_GPA                                                        0
# Year_2023                                                        78
# Academic_GPA_2023                                                 0
# Monthly_Allowance                                                31
# Scholarship                                                      54
# Study_hours                                                       3
# Socialsing                                                        2
# Alcohol_Drinks                                                    2
# Classes_Missed                                                    3
# Modules_Failed                                                    0
# Relationship                                                      3
# Parent_Approval                                                   4
# Parent_Relationship                                               0
# Sex_Male                                                          0
# ...

# %%
print(
    (data.isnull().sum() / len(data) * 100).round(2)
)
# Out:
# Matric_GPA                                                        0.00
# Year_2023                                                        19.21
# Academic_GPA_2023                                                 0.00
# Monthly_Allowance                                                 7.64
# Scholarship                                                      13.30
# Study_hours                                                       0.74
# Socialsing                                                        0.49
# Alcohol_Drinks                                                    0.49
# Classes_Missed                                                    0.74
# Modules_Failed                                                    0.00
# Relationship                                                      0.74
# Parent_Approval                                                   0.99
# Parent_Relationship                                               0.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 22 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Matric_GPA                                                     406 non-null    float64
#  1   Year_2023                                                      328 non-null    float64
#  2   Academic_GPA_2023                                              406 non-null    float64
#  3   Monthly_Allowance                                              375 non-null    float64
#  4   Scholarship                                                    352 non-null    float64
#  5   Study_hours                                                    403 non-null    float64
#  6   Socialsing                                                     404 non-null    object
# ...

# %%
missing = data.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)

missing.plot(
    kind="bar",
    figsize=(10,5),
    title="Remaining Missing Values"
)

plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
data = data.drop(columns=["Scholarship"])

# %%
numeric_cols = data.select_dtypes(include=["int64", "float64"]).columns

for col in numeric_cols:
    data[col] = data[col].fillna(data[col].median())

# %%
categorical_cols = data.select_dtypes(include=["object"]).columns

for col in categorical_cols:
    data[col] = data[col].fillna(data[col].mode()[0])

# %%
data.isnull().sum()
# Out:
# Matric_GPA                                                       0
# Year_2023                                                        0
# Academic_GPA_2023                                                0
# Monthly_Allowance                                                0
# Study_hours                                                      0
# Socialsing                                                       0
# Alcohol_Drinks                                                   0
# Classes_Missed                                                   0
# Modules_Failed                                                   0
# Relationship                                                     0
# Parent_Approval                                                  0
# Parent_Relationship                                              0
# Sex_Male                                                         0
# Faculty_Arts & Social Sciences                                   0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 21 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Matric_GPA                                                     406 non-null    float64
#  1   Year_2023                                                      406 non-null    float64
#  2   Academic_GPA_2023                                              406 non-null    float64
#  3   Monthly_Allowance                                              406 non-null    float64
#  4   Study_hours                                                    406 non-null    float64
#  5   Socialsing                                                     406 non-null    object
#  6   Alcohol_Drinks                                                 406 non-null    float64
# ...

# %%
data.head()
# Out:
#    Matric_GPA  Year_2023  Academic_GPA_2023  Monthly_Allowance  Study_hours  \
# 0        76.0        2.0               72.0                1.0          4.0
# 1        89.0        2.0               75.0                4.0          4.0
# 2        76.0        1.0               55.0                1.0          2.0
# 3        89.0        2.0               84.0                3.0          2.0
# 4        74.0        2.0               52.0                1.0          2.0
#
#       Socialsing  Alcohol_Drinks  Classes_Missed  Modules_Failed  \
# 0  Only weekends             4.0             3.0             0.0
# 1  Only weekends             2.0             4.0             0.0
# 2              2             4.0             3.0             0.0
# 3              3             4.0             2.0             0.0
# 4  Only weekends             3.0             1.0             3.0
#
#    Relationship  ...  Parent_Relationship  Sex_Male  \
# 0           1.0  ...                  3.0     False
# ...
