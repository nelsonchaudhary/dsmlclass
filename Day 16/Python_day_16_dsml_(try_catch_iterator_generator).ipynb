# %% [markdown]
# #iterator

# %%
num = [1,2,3]
it = iter(num)

# %%
print(next(it))
# Out:
# 1

# %%
print(next(it))
# Out:
# 2

# %%
print(next(it))
# Out:
# 3

# %%
print(next(it))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_649/962129236.py in <cell line: 0>()
# ----> 1 print(next(it))
#
# StopIteration:

# %%
#iterable
lst = [1,2,3]
for i in lst:
  print(i)
# Out:
# 1
# 2
# 3

# %%
num = [1,2,3]
it = iter(num)

# %%
it

# %%
next(it)
# Out:
# 1

# %%
for i in it:
  print(i)
# Out:
# 2
# 3

# %%
def count_up(n):
  i = 1
  while i<=n:
    yield i    # yield - pause here and return a value,but remember the current state of the function
    i +=1

# %%
gent = count_up(3)

# %%
gent
# Out:
# <generator object count_up at 0x7a38e35ba2c0>

# %%
print(next(gent))
# Out:
# 1

# %%
print(next(gent))
# Out:
# 2

# %%
print(next(gent))
# Out:
# 3

# %% [markdown]
# ![Screenshot 2026-07-24 163758.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-24 163849.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-24 164323.png](data:image/png;base64,...)

# %% [markdown]
# #Error handling
# exceptions and exception handling

# %% [markdown]
# ![Screenshot 2026-07-24 165053.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-07-24 171424.png](data:image/png;base64,...)

# %%
# server 1000 mb ko cha data 2000 mb

# %%
#try:
#expect
#else:
#finally:

try:
  numerator = int(input("Enter a number to divide : "))
  denominator = int(input("Enter a number to divide by :"))
  result = numerator/denominator
except ZeroDivisionError:
  print("Error : Cannot divide by zero!")
except ValueError:
  print("Error : Invalid input . Please enter a valid number")
else:
  print(f"the result is {result}")
finally:
  print("Execution complete.")
# Out:
# Enter a number to divide : 10
# Enter a number to divide by :2
# the result is 5.0
# Execution complete.

# %% [markdown]
# ![Screenshot 2026-07-24 170311.png](data:image/png;base64,...)

# %%
#ZeroDivisionError

num = 10
result = num/0
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_649/2373777203.py in <cell line: 0>()
#       2
#       3 num = 10
# ----> 4 result = num/0
#       5 print(result)
#
# ZeroDivisionError: division by zero

# %%
#TypeError

a = "hello"
b = 12
result = a+b
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_649/2135499055.py in <cell line: 0>()
#       3 a = "hello"
#       4 b = 12
# ----> 5 result = a+b
#       6 result
#
# TypeError: can only concatenate str (not "int") to str

# %%
#ValueError

a = int(input("num1 "))
b = int(input("num2 "))
result = a * b
result
# Out:
# num1 10
# num2 as
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_649/3831723995.py in <cell line: 0>()
#       2
#       3 a = int(input("num1 "))
# ----> 4 b = int(input("num2 "))
#       5 result = a * b
#       6 result
#
# ValueError: invalid literal for int() with base 10: 'as'

# %%
#NameError

data = [
    {"name":nelson}
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_649/3518437972.py in <cell line: 0>()
#       2
#       3 data = [
# ----> 4     {"name":nelson}
#       5 ]
#
# NameError: name 'nelson' is not defined

# %%
#IndexError

num = [10,20,30]

print(num[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_649/1320597693.py in <cell line: 0>()
#       3 num = [10,20,30]
#       4
# ----> 5 print(num[5])
#
# IndexError: list index out of range

# %%
#KeyError
data = {"name":"nelson","age":23}
print(data["address"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2557/1605666617.py in <cell line: 0>()
#       1 #KeyError
#       2 data = {"name":"nelson","age":23}
# ----> 3 print(data["address"])
#
# KeyError: 'address'

# %%
#FileNotFoundError
file = open("sample.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_649/803057531.py in <cell line: 0>()
#       1 #FileNotFoundError
# ----> 2 file = open("sample.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %% [markdown]
# #Error raise

# %%
def set(age):
  if age < 0:
    raise ValueError("age cannot be negative")
  print(f"Age set to {age}")

# %%
try:
  set(-5)
except ValueError as e:
  print(e)
# Out:
# age cannot be negative

# %% [markdown]
# #custom Expection<br>
# self made error type

# %%
#custom Expection

class InvalidAgeError(Exception):
  """Custom expection for invalid age values"""
  pass

def set_age_custom(age):
  if age>120:
    raise InvalidAgeError("age cannot be over 120")

# %%
set_age_custom(140)
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeError                           Traceback (most recent call last)
# /tmp/ipykernel_649/1011916966.py in <cell line: 0>()
# ----> 1 set_age_custom(140)
#
# /tmp/ipykernel_649/3951109346.py in set_age_custom(age)
#       7 def set_age_custom(age):
#       8   if age>120:
# ----> 9     raise InvalidAgeError("age cannot be over 120")
#
# InvalidAgeError: age cannot be over 120
