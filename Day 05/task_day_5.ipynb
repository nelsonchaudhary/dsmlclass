# %% [markdown]
# #Create a list of 5 favorite fruits. Add one more
# #fruit using append() and print the updated list.

# %%
data = ["apple","mango","banana","pineapple","guava"]
fruit  = input("enter a fruit name = ")
data.append(fruit)
print(data)
# Out:
# enter a fruit name = coconut
# ['apple', 'mango', 'banana', 'pineapple', 'guava', 'coconut']

# %% [markdown]
# #Create a list of numbers from 1 to 5. Remove
# #the last item using pop() and print the final list.

# %%
data = [1,2,3,4,5]
data.pop()
data
# Out:
# [1, 2, 3, 4]
